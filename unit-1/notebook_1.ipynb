# %% [markdown]
# <a href="https://colab.research.google.com/github/wbandabarragan/quantum-mechanics-1/blob/main/unit-1/notebook_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Test notebook:
#
# ## W. Banda-Barragán
#
# Open it on Google Colab or in your own Conda installations.
#
# 1) Check where we are, we can use bash commands in a jupyter notebook with "!" e.g.

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# 2) Check the python version:

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
4. + 3.
# Out:
# 7.0

# %% [markdown]
# 3) Now, let's import a few libraries, there should be no errors:

# %%
# Importing libraries

import numpy as np
import matplotlib.pyplot as plt

# %%
# Test
print(np.pi)
# Out:
# 3.141592653589793

# %% [markdown]
# 4) Now, let's make a simple plot:

# %%
# Vectors for the X axis and Y axis

x = np.arange(-2*np.pi, 2*np.pi, 0.01)

y = np.cos(x)

print(x.shape, y.shape)
# Out:
# (1257,) (1257,)

# %%
# For the plot we use Matplotlib

plt.figure(figsize = (5,4))

plt.plot(x, y, color = "magenta", linestyle = ":", label = r"$y = \cos(x)$")

plt.xlabel(r"$x$")
plt.ylabel(r"$y$")

plt.legend(loc=1)

plt.show()

# %%
# Another Y axis

y_1 = x
y_2 = np.sin(x)

# %%
# For the plot we use Matplotlib

plt.figure(figsize = (6,5))

plt.plot(x, y, color = "red", label = r"$y = \cos(x)$")
plt.plot(x, y_1, color = "blue", label = r"$y = x$")
plt.plot(x, y_2, color = "green", label = r"$y = \sin(x)$")

plt.xlabel(r"$x$")
plt.ylabel(r"$y$")

plt.legend(loc=4)
plt.show()

# %% [markdown]
# 5) Surface plots:
#
#
# $$z = \sin\left(\sqrt{x^2+y^2}\right)$$

# %%
# Let's define a python function

def surface_1(x_2D, y_2D):
  """
  This is a function to create a 2D surface.
  Inputs: x_2D, y_2D
  Outputs: z_2D
  """

  z_2D = np.sin(np.sqrt(x_2D**2 + y_2D**2))

  return z_2D

# %%
help(surface_1)
# Out:
# Help on function surface_1 in module __main__:
#
# surface_1(x_2D, y_2D)
#     This is a function to create a 2D surface.
#     Inputs: x_2D, y_2D
#     Outputs: z_2D

# %%
# We need to create a 2D grid, based on 1D vectors

# Let's create the 1D vectors
x = np.linspace(-10., 10., 400)
y = np.linspace(-10., 10., 400)

# Now we need the 2D grid
x_2D, y_2D = np.meshgrid(x, y)

print(x.shape, x_2D.shape)
print(y.shape, y_2D.shape)

# Call the surface function
z_2D = surface_1(x_2D, y_2D)

print(z_2D.shape)
# Out:
# (400,) (400, 400)
# (400,) (400, 400)
# (400, 400)

# %%
# Plotting

plt.figure()

ax = plt.axes(projection = "3d")

ax.contour3D(x_2D, y_2D, z_2D, 100, cmap = 'magma')

ax.set_xlabel('x')  # Customised labels for axes
ax.set_ylabel('y')
ax.set_zlabel('z')

plt.show()

# %%
# Plotting

plt.figure(figsize=(5,4))

plt.pcolor(x_2D, y_2D, z_2D, cmap = 'magma')

plt.xlabel('x')  # Customised labels for axes
plt.ylabel('y')

plt.show()

# %%
# Plotting

plt.figure(figsize=(5,4))

plt.contour(x_2D, y_2D, z_2D, cmap = 'magma')

plt.xlabel('x')  # Customised labels for axes
plt.ylabel('y')

plt.show()

# %%
# Plotting

plt.figure(figsize=(5,4))

plt.contourf(x_2D, y_2D, z_2D, cmap = 'magma')

plt.xlabel('x')  # Customised labels for axes
plt.ylabel('y')

plt.show()
